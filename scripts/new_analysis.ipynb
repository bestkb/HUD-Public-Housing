# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
inspection_score_with_tracs = pd.read_csv('https://raw.githubusercontent.com/bestkb/HUD-Public-Housing/main/data/locations_inspectionscores_w_tracts.csv')
inspection_score_with_tracs
# Out:
#       DEVELOPMENT_ID                          DEVELOPMENT_NAME  CBSA_CODE  \
# 0        LA130000001                   Duson Housing Authority    29180.0
# 1        GA006000772                      CENTENNIAL PLACE III    12060.0
# 2        GA006000770                        CENTENNIAL PLACE I    12060.0
# 3        DC001001830                           SCATTERED SITES    47900.0
# 4        CA019000180                           SCATTERED SITES    40140.0
# ...              ...                                       ...        ...
# 53759    WI214000001                  STOUGHTON HSG/SCAT SITES    31540.0
# 53760    WV011000001  DORSEY ST/BURLEY/FRANCINE/KERMIT/GATTSCT    48540.0
# 53761    PA001000044                          FINELLO PAVILION    38300.0
# 53762    LA013000013                         ACRE ROAD PROJECT    35380.0
# 53763    TN040000001                             WILLOW COURTS    99999.0
#
#                 COUNTY_NAME  COUNTY_CODE STATE_NAME.x  STATE_CODE  ZIPCODE  \
# ...

# %%
raw_county_data = pd.read_csv('https://raw.githubusercontent.com/bestkb/HUD-Public-Housing/main/data/raw_county_data.csv')
raw_county_data
# Out:
#        GEOID  age_c  total_pop_c  total_white_c  total_black_c  \
# 0       1001   36.0        49584          38636           8827
# 1       1003   41.0       171997         146381          16851
# 2       1005   37.5        29663          14251          13724
# 3       1007   38.6        21464          16182           4953
# 4       1009   38.2        56804          50787            473
# ...      ...    ...          ...            ...            ...
# 38641  72145   42.4        51089           1347              8
# 38642  72147   43.8         8508            520             28
# 38643  72149   41.3        21899             36             17
# 38644  72151   44.1        32867             22              0
# 38645  72153   45.1        34501            138             23
#
#        total_hispanic_c  poverty_c  income_c  public_assistance_c  owner_c  \
# 0                  1012    13305.0   51463.0              18288.0    14182
# ...

# %%
raw_tract_data = pd.read_csv('https://raw.githubusercontent.com/bestkb/HUD-Public-Housing/main/data/raw_tract_data.csv')
raw_tract_data
# Out:
#               GEOID   age  total_pop  total_white  total_black  \
# 0       22001960100  36.1       6541         4436         1983
# 1       22001960200  40.5       4827         4454          226
# 2       22001960300  37.4       3679         3568           30
# 3       22001960400  32.2       5878         5539          263
# 4       22001960500  35.7       5429         4933          403
# ...             ...   ...        ...          ...          ...
# 880431  56043000200  48.9       3124         2900            1
# 880432  56043000301  37.1       2231         1611            0
# 880433  56043000302  37.6       2578         1976            0
# 880434  56045951100  48.4       3276         2885           44
# 880435  56045951300  38.2       3666         3408            0
#
#         total_hispanic  poverty   income  public_assistance  owner  renter  \
# 0                   61   1780.0  26335.0             2613.0   1555    1058
# ...

# %%
locations_inspectionscores = pd.read_csv('https://raw.githubusercontent.com/bestkb/HUD-Public-Housing/main/data/tract_demographics_forMeri_Feb.csv')
locations_inspectionscores
# Out:
#        DEVELOPMENT_ID   block_group   county         tract  age_c  \
# 0         LA130000001  2.205500e+11  22055.0  2.205500e+10   34.9
# 1         LA130000001  2.205500e+11  22055.0  2.205500e+10   33.7
# 2         LA130000001  2.205500e+11  22055.0  2.205500e+10   31.9
# 3         LA130000001  2.205500e+11  22055.0  2.205500e+10   30.8
# 4         LA130000001  2.205500e+11  22055.0  2.205500e+10   29.6
# ...               ...           ...      ...           ...    ...
# 101789    OH001000236  3.904900e+11  39049.0  3.904900e+10   37.9
# 101790    OH001000236  3.904900e+11  39049.0  3.904900e+10   39.8
# 101791    OH001000236  3.904900e+11  39049.0  3.904900e+10   37.6
# 101792    OH001000236  3.904900e+11  39049.0  3.904900e+10   37.2
# 101793    OH001000236  3.904900e+11  39049.0  3.904900e+10   38.4
#
#         total_pop_c  total_white_c  total_black_c  total_hispanic_c  \
# 0            4807.0         2821.0         1895.0               0.0
# ...

# %%
tract_demographics = pd.read_csv('https://raw.githubusercontent.com/bestkb/HUD-Public-Housing/main/data/locations_inspectionscores_forMeri_Feb.csv')
tract_demographics
# Out:
#       DEVELOPMENT_ID                          DEVELOPMENT_NAME  CBSA_CODE  \
# 0        LA130000001                   Duson Housing Authority    29180.0
# 1        GA006000772                      CENTENNIAL PLACE III    12060.0
# 2        GA006000770                        CENTENNIAL PLACE I    12060.0
# 3        DC001001830                           SCATTERED SITES    47900.0
# 4        CA019000180                           SCATTERED SITES    40140.0
# ...              ...                                       ...        ...
# 53759    WI214000001                  STOUGHTON HSG/SCAT SITES    31540.0
# 53760    WV011000001  DORSEY ST/BURLEY/FRANCINE/KERMIT/GATTSCT    48540.0
# 53761    PA001000044                          FINELLO PAVILION    38300.0
# 53762    LA013000013                         ACRE ROAD PROJECT    35380.0
# 53763    TN040000001                             WILLOW COURTS    99999.0
#
#                 COUNTY_NAME  COUNTY_CODE STATE_NAME.x  STATE_CODE  ZIPCODE  \
# ...

# %%
# over time (data available) the mean inspection score in the us
