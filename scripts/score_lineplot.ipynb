# %%
import os
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/dataframe.csv')

# %%
df.set_index('region', inplace=True)

# %%
df.to_csv('temp.csv')
df = pd.read_csv('temp.csv')
os.remove('temp.csv')

# %%
df
# Out:
#    region  2008  2009  2010  2011  2013  2014  2015  2016  2017  2018  2019  \
# 0       1  76.5  85.0  83.0  79.0  84.0  88.5  92.0  83.0  86.5  84.0  87.0
# 1       2  81.0  74.5  75.0  72.0  79.0  86.0  82.0  78.5  74.0  73.0  68.0
# 2       3  80.5  80.0  78.0  61.0  81.0  86.0  89.0  86.0  80.0  79.0  76.0
# 3       4  82.0  84.0  84.0  86.0  88.0  88.0  91.0  86.0  85.0  82.0  82.0
# 4       5  83.0  81.0  80.0  87.0  83.0  85.0  88.0  83.0  80.0  78.0  84.0
# 5       6  83.0  83.0  82.0  85.0  87.0  90.0  88.0  86.0  83.0  77.0  77.0
# 6       7  93.0  91.0  87.0  92.5  91.0  92.0  93.0  89.0  87.0  85.0  83.0
# 7       8  83.0  86.0  86.0   NaN  83.0  86.0  95.0  89.0  83.0  83.5  83.0
# 8       9  76.0  86.0  81.0  81.0  85.0  90.0  86.0  85.0  85.0  84.0  79.0
# 9      10  93.0  91.0  89.0  93.0  97.0  92.0  89.5  88.0  84.0  85.5  80.0
#
#    2020  2012  2005
# 0  77.0   NaN   NaN
# 1  67.0   NaN   NaN
# 2  73.0   NaN   NaN
# 3  80.0  87.5   NaN
# 4  77.0  82.0   NaN
# 5  81.0   NaN  97.0
# 6  75.0   NaN   NaN
# 7  75.0   NaN   NaN
# 8  86.0   NaN   NaN
# 9  78.5   NaN   NaN

# %%
index = df['region']
df.drop(columns=['2012', '2005'], inplace=True)

# %%
df
# Out:
#    region  2008  2009  2010  2011  2013  2014  2015  2016  2017  2018  2019  \
# 0       1  76.5  85.0  83.0  79.0  84.0  88.5  92.0  83.0  86.5  84.0  87.0
# 1       2  81.0  74.5  75.0  72.0  79.0  86.0  82.0  78.5  74.0  73.0  68.0
# 2       3  80.5  80.0  78.0  61.0  81.0  86.0  89.0  86.0  80.0  79.0  76.0
# 3       4  82.0  84.0  84.0  86.0  88.0  88.0  91.0  86.0  85.0  82.0  82.0
# 4       5  83.0  81.0  80.0  87.0  83.0  85.0  88.0  83.0  80.0  78.0  84.0
# 5       6  83.0  83.0  82.0  85.0  87.0  90.0  88.0  86.0  83.0  77.0  77.0
# 6       7  93.0  91.0  87.0  92.5  91.0  92.0  93.0  89.0  87.0  85.0  83.0
# 7       8  83.0  86.0  86.0   NaN  83.0  86.0  95.0  89.0  83.0  83.5  83.0
# 8       9  76.0  86.0  81.0  81.0  85.0  90.0  86.0  85.0  85.0  84.0  79.0
# 9      10  93.0  91.0  89.0  93.0  97.0  92.0  89.5  88.0  84.0  85.5  80.0
#
#    2020
# 0  77.0
# 1  67.0
# 2  73.0
# 3  80.0
# 4  77.0
# 5  81.0
# 6  75.0
# 7  75.0
# 8  86.0
# 9  78.5

# %%
df.dtypes
# Out:
# region      int64
# 2008      float64
# 2009      float64
# 2010      float64
# 2011      float64
# 2013      float64
# 2014      float64
# 2015      float64
# 2016      float64
# 2017      float64
# 2018      float64
# 2019      float64
# 2020      float64
# dtype: object

# %%
df.set_index('region', inplace=True)

# %%
print(df.dtypes)
# Out:
# 2008    float64
# 2009    float64
# 2010    float64
# 2011    float64
# 2013    float64
# 2014    float64
# 2015    float64
# 2016    float64
# 2017    float64
# 2018    float64
# 2019    float64
# 2020    float64
# dtype: object

# %%
plt.figure(figsize=(12, 6))

for region in df.index:
    plt.plot(df.columns, df.loc[region], marker='o', markersize=5, label=f'{region}')


plt.xlabel('Year')
plt.ylabel('Inspection Score')
plt.title('Inspection score over the years in different FEMA Regions')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
